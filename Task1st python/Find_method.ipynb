# %% [markdown]
# **Find method**

# %%
print("python programming".find("pro"))
print("data analytics".find("ana"))
print("hello sir".find("sir"))
print("student batch".find("bat"))
print("good morning".find("mor"))
# Out:
# 7
# 5
# 6
# 8
# 5
