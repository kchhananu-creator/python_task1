# %% [markdown]
# **Lower method**

# %%
print("ARC".lower())
print("DATA ANALYTICS".lower())
print("PYTHON CLASS".lower())
print("HELLO SIR".lower())
print("NAGPUR CITY".lower())
# Out:
# arc
# data analytics
# python class
# hello sir
# nagpur city
