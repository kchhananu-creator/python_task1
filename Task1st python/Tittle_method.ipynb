# %% [markdown]
# **Tittle method**

# %%
# TITLE METHOD
print("arc batch".title())
print("data analytics subject".title())
print("python programming".title())
print("good morning".title())
print("student record".title())
# Out:
# Arc Batch
# Data Analytics Subject
# Python Programming
# Good Morning
# Student Record
