# %% [markdown]
# **count**

# %%
print("banana".count("a"))
print("data analytics".count("a"))
print("hello hello".count("lo"))
print("python class".count("s"))
print("good good".count("good"))
# Out:
# 3
# 4
# 2
# 2
# 2
