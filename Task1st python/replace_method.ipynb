# %% [markdown]
# ****Replac Method**

# %%
print("I like java".replace("java","python"))
print("data science class".replace("science","analytics"))
print("hello student".replace("student","sir"))
print("my city nagpur".replace("nagpur","mumbai"))
print("good night".replace("night","morning"))
# Out:
# I like python
# data analytics class
# hello sir
# my city mumbai
# good morning
